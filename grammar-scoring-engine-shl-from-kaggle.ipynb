# %%
# If running on Kaggle, install xgboost
# !pip install xgboost

# %%
from xgboost import XGBRegressor

# %%
# Original code may look something like this
# from sklearn.ensemble import RandomForestRegressor
# model = RandomForestRegressor()
# Updated code below:
model = XGBRegressor()

# %%
# Ensure other parameters passed and usage are compatible with XGBoost
# Example: if RandomForestRegressor had n_estimators, it can also be passed here
model = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=6)
